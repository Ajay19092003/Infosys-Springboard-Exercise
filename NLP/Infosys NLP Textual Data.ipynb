# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import string
import matplotlib.pyplot as plt
from collections import Counter

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')

# Load and read the text file
with open('sample1.txt', 'r') as file:
    text = file.read()

# Tokenize the text
tokens = word_tokenize(text)

# Count number of unique tokens
unique_tokens = set(tokens)
num_unique_tokens = len(unique_tokens)
print(f"Number of unique tokens: {num_unique_tokens}")

# Count number of punctuation characters
punctuation_count = sum(1 for token in tokens if token in string.punctuation)
print(f"Number of punctuation characters: {punctuation_count}")

# Plot POS tag distribution
pos_tags = pos_tag(tokens)
tag_counts = Counter(tag for word, tag in pos_tags)
plt.figure(figsize=(10, 6))
plt.bar(tag_counts.keys(), tag_counts.values())
plt.title('POS Tag Distribution')
plt.xlabel('POS Tags')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Lemmatize tokens and count unique lemmas
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(token) for token in tokens]
unique_lemmas = set(lemmas)
num_unique_lemmas = len(unique_lemmas)
print(f"Number of unique lemmas: {num_unique_lemmas}")

# Plot stopwords distribution
stop_words = set(stopwords.words('english'))
stopwords_counts = Counter(token.lower() for token in tokens if token.lower() in stop_words)
plt.figure(figsize=(10, 6))
plt.bar(stopwords_counts.keys(), stopwords_counts.values())
plt.title('Stopwords Distribution')
plt.xlabel('Stopwords')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AjayG\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\AjayG\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\AjayG\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AjayG\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# Number of unique tokens: 172
# Number of punctuation characters: 33
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ...
